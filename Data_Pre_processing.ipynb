# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING =  'emotion-recognition-dataset:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F4123094%2F7143293%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240417%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240417T114636Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'
KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading emotion-recognition-dataset, 2126237709 bytes compressed
# [==================================================] 2126237709 bytes downloaded
# Downloaded and uncompressed: emotion-recognition-dataset
# Data source import complete.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# This part of the code has been adapted from https://www.kaggle.com/code/krishnasrivaibhav/emotion-recognition-resnet152-architecture

# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Streaming output truncated to the last 5000 lines.
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264843~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260698~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1d2d1d77af5a1db07d9ecc3073b29788423a035c4a21498b9a23b781~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414866~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265474~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414906~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100210~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264945~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414911~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0e0448eae102baed45e59d36a38a793c0d93c6e07e6e0e2ae11eba22~12fffff.jpeg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.266722~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100180~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267713~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0e7e66d0d7cd5263d9d7ff70a534804cecd66d865fff9c24d1ff4eea~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265909~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262299~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260779~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415027~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414886~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260184~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262952~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100054~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100000~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100121~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260739~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414889~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1c06a2502e334bba029c1d76b120252205df66389c9580c527eaa968~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261274~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268569~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100084~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267744~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260846~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262197~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414859~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100219~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267736~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267234~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261449~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414955~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263046~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100208~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100017~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260178~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415020~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0a85885c84659ed4bfad88c109c72f4e94955fa865838744b993b238~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260309~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100232~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260182~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267703~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260809~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268378~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267228~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267922~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100202~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264589~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261632~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268544~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261314~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260918~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261389~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261661~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261292~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262303~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260462~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260439~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265041~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264279~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264131~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262750~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414940~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268206~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100256~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264591~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262602~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263791~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263807~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264919~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267822~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260506~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415023~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414965~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260110~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261827~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260003~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261295~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1f35e7a18e1d3a1909aeaeac94e6d7bfda684f797cff5e3c3a596f08~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265749~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.259973~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267799~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261028~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100272~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100001~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262315~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263056~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414860~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100163~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264801~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260175~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0c24176207ea093b0afcc2102cea438e565c27815794e0a2d4108c64~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267697~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100109~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414922~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100014~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262554~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100167~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414863~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263868~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262635~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262677~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262257~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265363~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260222~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260011~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100100~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100103~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414963~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100218~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414964~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262202~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267563~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260316~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261262~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415055~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261829~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100031~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100090~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100248~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268560~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414956~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.99996~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265096~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414836~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0f58325755c7f11f1a430695039d7db02b0068db38c4dcf1885c1338~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100058~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261446~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264814~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100225~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414854~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414960~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.99987~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100147~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260420~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267604~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268019~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262416~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260780~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1f271ee50de2e6fb016512977def120dc40f2cad003b511ccc7ab30d~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415004~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261199~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100171~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100123~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262749~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0afab74a591c61ba239c8f0389041a3003a0215214d513fa89f1b99a~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260913~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0ab658dbcca7a9cb8e4570106c42869aaef90793f4c065a097202742~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0ca598fc86a2616437158c2976ca8277a9d8779d4f436f6f1967e02e~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264831~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267389~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100111~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414991~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1c316415b637a42bb4fad009c5063af0c7dd969fecfb62be1f0dfe5c~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1bd930d6a1c717c11be33db74823f661cb53f86cbba1d3d1f336cdf9~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415048~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1d21cce68f759891e2dec0de5d65072c83e4ec089c28cb8180e8c155~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262098~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267274~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263389~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261049~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0de2b1dfd4b0c733bc42db283ba1f3535640affea26bf920e3edadea~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414993~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261912~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.266304~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262781~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260677~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267105~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262527~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262031~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414834~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265000~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414843~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261836~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262503~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261462~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263989~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260328~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263521~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100073~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260542~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261921~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100104~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.99991~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260480~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414910~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261045~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265438~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261630~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262493~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414988~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261901~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415012~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265264~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0e97678fc308afc35604f85896912faaee98b33c4d46feb8f8b68f0d~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100018~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265858~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0b0efc3325f39127a57a380aaed04fc49503e53cdf59dd64b1dae4a3~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414981~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260593~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267910~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267943~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267672~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265659~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.266531~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260485~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261448~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264079~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260290~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260583~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.99986~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265003~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260703~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260423~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262179~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.269276~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262551~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415017~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100053~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263498~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415006~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100098~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414858~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414847~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1f0cff9a3d005123686525e00e4942b29c758f4637b30f7d339dfa89~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414939~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100005~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264961~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267593~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100072~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262377~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268441~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265835~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268258~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261812~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414857~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415016~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260447~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262323~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.99985~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268248~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100138~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268550~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260607~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100198~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268220~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263239~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0a29ef6f5e1110b20073182cbc98fab0c95d502920b6b6b2bbdf27cc~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260220~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100011~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1d697c3698296cab86d9e9e87a2885457844e9dc48b8c8a1397ec9f9~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267598~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100193~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1a90785f9b8317df3fa7afaef881bf4808c67b4406a46ac270b193e4~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415015~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100215~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260736~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414844~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260252~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261459~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414840~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100025~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100099~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.266627~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268568~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100110~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263433~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.99994~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261483~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260556~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267246~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100238~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268506~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261361~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262546~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100077~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100242~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260971~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.99981~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262962~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261937~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262379~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415025~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264709~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0bff78216369acf844f5fe5a79262e3de0b03aae090cdc92f9d5c270~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.99977~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260261~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414833~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414990~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262129~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261493~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261862~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265556~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261291~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.259967~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414944~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100243~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262777~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100191~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265150~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260906~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265788~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415050~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100114~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414926~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414978~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414967~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260912~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267520~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261357~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261393~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100043~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260140~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261356~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260301~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261461~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100107~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100201~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260337~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414942~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267150~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260215~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100102~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267786~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100217~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415047~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262198~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262349~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262064~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1b7be984c0cc5768f93cd1652902953cce79ea7510d755388cfa74b7~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100189~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261101~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267784~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414989~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414919~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263185~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260073~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.269294~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.266790~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100146~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261584~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268597~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267870~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260277~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267714~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100133~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260185~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0e7c47516e336d748c5503358e4547142e270a68434e4d74d4bb66fd~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265489~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265364~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100039~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260310~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100275~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1df412d2dff8456fa077d4ac897550b30278dc42115946148a211e84~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267839~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268012~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100279~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414932~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100040~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262014~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100183~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268157~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261653~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261993~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.266626~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260274~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414933~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260398~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262791~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100080~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268482~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260349~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267871~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263316~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414987~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.266100~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261111~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415044~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0b1ad3c48d366b223e487bba5d658efa5ac52d2daa093a222362029e~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414894~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100172~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263099~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100135~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261913~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.259998~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414934~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261148~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262018~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261742~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265417~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415043~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267645~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263627~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414997~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100050~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260030~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261112~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260015~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264750~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268364~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268288~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261717~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100244~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260606~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414888~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0cde5914bf58bb0b3a601d45ad58c6eebd7a1ffa7ee5de60eea7d179~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262509~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.266532~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261643~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260055~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415001~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100259~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264130~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268559~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100022~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267944~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265245~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264187~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261536~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414968~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415054~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414973~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267568~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268418~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415026~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264833~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260169~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414971~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264797~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265575~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.266104~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414855~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100220~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262270~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100173~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100186~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0bb98d918a09c510b4b6a79a8862e40c541100bbe4f0f1c0d4a2696d~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264726~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260017~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414953~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414954~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415045~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268538~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0a21ab4e2f58256a4dc24cbf75d491acab77eab3d75837983af6c019~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265551~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260191~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0b85c4327bb8dd9659e8ed1140a122819809c130827b6859b0acf559~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.262286~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268377~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263331~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100199~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.415018~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260692~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414878~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100262~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100061~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267217~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265929~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265179~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/1f5643c64ad33aa30d8a2d3bc232c6a7fab73243e4d57fcbc24eed2d~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0d5e0d3dcc227525f4caa5f2289198fa41573707e3c0051cdb5a2918~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260479~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.259931~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414838~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100207~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414966~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414920~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267616~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263337~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.264669~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267564~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414970~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.265042~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261042~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.261615~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260145~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.268276~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.414959~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.100012~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.260855~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263583~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/0dcc9de28d2c067ba2d4672072b148e03d03965bcc944bbe592f350b~12fffff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.99988~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263366~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.267840~12fffff.png
# /kaggle/input/emotion-recognition-dataset/dataset/Surprise/cropped_emotions.263794~12fffff.png
# ...
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0ba9933a4d919d2dc0eb9ea7ee9d37ededba93d810a63afa7748a5b3f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c497ded4f6eb5278aef3c576930ddf910b809a7cd7ede9ee49c0e75f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0e85d6386f9d44c6b33c91eeb3b9c070f4d4512b07aaba1184ea97faf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278373f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277818f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278077f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278032f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/1adde9e755c7bf3c9ed00ef70fd269ff5f321be9f29bef3c03a2b4d6f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0de51e08644e6d6e28b2df01186da14221b1820413dc63d639da0859f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0b078716a15ec3cb7961e2be821347879096f906e0024d658d24b6ebf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c66ea38deda424bfa6428d1fc18943acb7f01093182d0e8d11d64b9f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/1ac83167cdf257e3df3914c34664bfa6cc988fb7261e2f442e5193b6f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c89f3630e95bd4709fecaadd0fd0e860f4b951e5bffc1bdbc35545ef.jpeg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277603f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0df60dfa3e4c275bf038128e9723041eb13ec9a7ec9f2d6c0e21c776f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278261f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278404f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0e1a24320d570539ddc602c2eeb9442fa7d0886489cb4f6a95320086f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278235f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277646f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0f961046272c9546388914051c9390c4176e52b2a8c82490fbc62503f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277943f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0b853c2817b99d80daeefff2f5be9a84b03cc89daa88ab13a0469bc6f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.171878f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0a71441e4bf5b9b12b4947919759f84d529fbe3ca88449673d4ae6b0f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0f64eb3926983805601686ca42391a1493193d7643a440d588b1a2c6f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0e9a642d7293107de982e3086be1c595b4af06215e36987ac41c72c7f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/1b2c347068009dafee64617c7c73c06ffc26650dc0402450fd0edefdf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/1ab080cb57b64954913739aaf9112e5d4e68945f7e578c4f73f3be96f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277861f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0a14144628cd66031b870fcd15634d23288307350e61769ab3ea704df.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c69827c94ad4fdd16ab309f8ac733b36f2ad04cfd8a0d25dacf2f51f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c184268b2c73032eb693ddbdae38a929f1308cd024ebcf742c49920f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0e6c25faa9e4e05f45178c4f15bcd28d64d06d26976527701d7cb9b0f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277681f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277647f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0fc0a0d4239a3b7b0acf6020b4db3dee3ee196fa57ad766c29591cd3f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0f7944a9e714d5db1906894a239d7e1fd07d41d5c386d61c622b9ff8f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0e67c3fb2cff219634c42b9f366a72bf16c5c9c5810a5bcdcfade935f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0f74af4d577433bae13447066e1123a7b023c700fdfc2372cd33fa03f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277652f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/00c02030f22dc72ed34228200dff9bcb3a5bed55c07fa9d4eb2059e3f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/00f8055b8638abf1a6867018ef0871027d666d7c0f339ce1c844f090f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278481f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0eb6cf866525ae6a00fd380523f8a06f9b9ad7dfbd428166d6101cc4f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0ecd4b9210c92b349bd6ade7d5f00806317ba5a61e2577839d73c0fbf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277957f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0f7edc28cbf22ba295e49b4020fd2ce631e1136721fa4bd67ce81b50f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0a43d2a3a241e016f5bc4fcc1d6222b9897feca0976bca6bf7b21721f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.452788f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0a4eda28a4c299a9c1367643b41bb9d1560f3255d56678c0a6aed22df.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0d8134466ec2d09d7c46df42070c226576a172f4e5e08e28131ae1e7f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0ff388514aa4207a63c011442ce36188e57f79c02990d49011dd66cbf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0fd59171e22ea9388124cf312ea421b78b4659ad14026d9b14ae63bff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.171743f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0d7178e63fa6f0f4ef4a0a42e60b835567821112eb1beb6ff9b0fc29f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0cc246b096e60086e06bb1361708a4f9bd12e37dab9731bcd5c2f43df.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/1aa29ca122a78e0aa80b159e5e7e56e000a449fd7db8a198aad968c6f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0b3bfff1b1b908758c41de68e6b723cc5db8b65f3fc629015bf61618f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/00af39ceb3b35434385119a239be1e5b259c012ba0f08857c757d307f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.452745f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/1aca0c3ca3792026ca903b2fb9049bf536ad22a0b7826fe4af556a8df.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0cf1c8cf3b9b20fd4e1d17c27bcd1de9361eb82e85663c3dfbdde2f9f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0a739a666ae232014a7c6d33b2c0dc7d3ee7ec882109f1511ed61db4f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0f9578380255460279668d3ede07f5c131cadd35e05496781cd24ae3f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/1aed201aeff0a371ec6d6591bc207b86edd819152008eb57871d2a05f.JPG
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0f82c80e9c9d4df092cc77f22d2b1413096518a160e9fe224d70deaaf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0a015cb3ea5a822547b757c0abfc1cd57d6b5ff9725bfb6de6972a0af.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.171907f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0aaf4bfe746bf33369ab0d3422d51078d200c94f6e77dc0e41d68219f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.452645f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.452816f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0b5367f69d4f5916ae05fd6e2f3294a56d2aa3fa6f591aec6f74768ff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0b2e7365f8acb90c6374aad287ae6a10337a1834a597adf611892f2cf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c7e74602dc76ed44e09144500828990bbd05385c518e9416f7f3129f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/1ae1cfcd9c84e9abd3f6e6d90885993325be26a027116548334bd735f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278121f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/000adf1bba31e39ce59b5222c82c89d61536a6c8bf1dd8ac50d99b3cf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0a9292dc2ee48bfbaf732c948d9f72f7ea61dd4df45d980dce6cc040f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0ff3d5edd5bd183669f0f5310686c1a83f3143f476b8a6c628087c17f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0df89cbc05cb5190fc3f95d220f80c485fff5b2b0ea8868b22e95289f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0df131ba8c791da82123c9fb57d8b25bd30ee7acc06ed4bd7575d392f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0d616523b52492bcf1057ed651659fd0fbfeb0b3c52b0717151e1d6df.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0cf8eeba0945569ec2eafbe3a85820d06ac5eb37002c28a9c77eda2bf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0d6cc421b6e6d983ad6e2c24e103d0d51a5df80f0fca09da20b34f3ff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278331f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0f291cc34ee8de8851266a8832fa85d2cb793f1e321b2d9c015ee69ef.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278412f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0e8ab8e0c10eb146f353dee92a481cd900c96c87912221eea3c1433bf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c67ad1699abb66fb904bd6f4b0bf18151911eb454aad76d3bfa634df.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/00ccc0c38de01be90949cc6201244fbc15c4cff6d204ad99f2e5d5d0f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/001a52769b7f46995c69bc903ec737a17486c5c506b59801ba27a70ff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0a3403f88ed9baedfd6d75a4496ad30e1ccef883900ae8ab61d2e709f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0d30b2abafab41ceb2ceb83e02b25aefc779974e9eb846726f2ad8f2f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0f3efb2e00585cca18dab4e10432ccf1ebbcf49e0e98616db5124519f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0b58e9952608b1cf4b1e04677cf24cb9a97e810169831ee3585f8f33f.jpeg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.452712f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/01a1606307d14c6aca45007ff5c9e3b27569115c5718e635023fe9dcf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277668f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0fddf0ea012dcfeb0a57bfee2cafe88bb4b21584168a96f75eea5de2f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277936f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.171806f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0f85d5064a856381c6264bb4f20973d6aa97ca34379305b761311830f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/1a49bd0c2ec0e6440c1d141edf7845b4a6f281a5320a15178957e03df.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0e0133eb5c61df233d4957dfc4fe898d55e274c10c7348e6adc26c51f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278059f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0f9357b4dc04799aab07f85d1a43e9d6de0aaef24a4ceb7f1c2bfeb0f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0b5f2658865f1196dd667ba71d8c0e564b3d9b874662f4eb85ef0605f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c34ed9774224661b4fe145eb7d989781ba9a7e4caad659bc52e303cf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0d74fe9d17422271015ea08c9846393394f3352bcfe5210a7ba83f42f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277619f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0de40b3d5e27245f39e7ff1c423480eb517e792ad9d156ee1af0586ef.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c154b7672240c287a92215c0b942327575710c5c61f0173378601b9f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0ae60b03dc8e9d660c015ca04e934f5ec3fde3f415e2ee8d234bc6d4f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0beeabf4283aa2824f333f91294851c68544bc21bda14af8b25a3152f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c702785a2366035270e53c753cf1e28d8d45745c52df0e2d1644537f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0fca540137634f593d6036178985d6422b2d5258bab9ecab4bcbce4cf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0e61fbbd5bff108d95825dc880f898e77f4d69e50e72f7e9f0728f82f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0d6ffbda1c0121b13443972dc4f5d9919dd61a9710d9ff53a0e67f7cf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/1a148a5e1b907348e72f4e23a0999bacb7931b09dc7b59f0a21bd8e8f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c5b3273d305b9a984bcbeb0c97bc9cca4a83b47d353393133d8e4d2f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0d856a56594e5cf64adc707b53e81efb24b3e53fd9c4e5ce16f73126f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.277672f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0e91ed5679d7b8e59f120c5ccba5bf879ab89c7ef294e957d4b812dcf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278421f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0d683d8648c64e1e4c6ec923c4e103a8959a151c4c7726be85e10696f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0a5333b343360cd9e0fb48a811d87b017badc0fe9ffc127932d16af7f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.452657f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0a5e0767e977d7440c7f06da7bf91cabec21247d7b8cf5b2fd11ccbbf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0bd4700b8776901eb0878f5cbd16551626f4997765ad70958e325d81f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0b1a541dcf152061a3823125e62f5df740efddaaff33a0e5fe73482ff.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/00b029289cb05cbfec7eaa149c85088cb0151d7646c083be95ce731ff(1).jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/1aa8c2ecb8a08dfa761d3449713cd61547ae1d1e1b0a16d3efa7049ef.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c991534e78f8d1569dcc95db54063e254d4cf231f5dfe4071cf1e45f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.278283f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/1ad481fc5906bbc27c9ef403f9a40858db99e5273fc8a80d958747eef.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c7f853e1b26781bf25eea4ba6580b28e4230dd56fa996df8b74ffebf.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0a1f205ce98aa31b1ec7516173d4e5ec9cdb7d37296f7f1ec0de1f06f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0ec5539c0ee9f21e35c693e8c88121ab2fd1cf3c421ea1b40b78a066f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/01a15f027662d2c69e373599ae4f5781f68c1405f83460f6c8a7d796f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0c4ac9cf0d52b13e72db4677adeb64e15b73d3ef4e41c896184165b0f.jpg
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/cropped_emotions.452785f.png
# /kaggle/input/emotion-recognition-dataset/dataset/Neutral/0f51e37ad68700905b5116003fe322ccb700d7286dd48fb99888ca7bf.jpg

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,BatchNormalization,Dropout,Flatten,MaxPooling2D,Conv2D,Activation
from sklearn.preprocessing import LabelEncoder,OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from PIL import Image
from sklearn.metrics import confusion_matrix,classification_report
import os
import glob

# %%
encoder=OneHotEncoder() # Adapted from https://www.kaggle.com/code/krishnasrivaibhav/emotion-recognition-resnet152-architecture
encoder.fit([[0],[1],[2],[3],[4],[5]])

# 0 = Ahegao
# 1 = Angry
# 2 = Happy
# 3 = Neutral
# 4 = Sad
# 5 = Surprise
# Out:
# OneHotEncoder()

# %%
data=[]
paths_ahegao=[]
result=[]

for r,d,f in os.walk('/kaggle/input/emotion-recognition-dataset/dataset/Ahegao'):
    for file in f:
        if '.jpg' or '.png' in file:
            paths_ahegao.append(os.path.join(r,file))
for path in paths_ahegao:
    img=Image.open(path)
    img=img.resize((128,128))
    img=np.array(img)
    if (img.shape==(128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
paths_angry=[]
for r,d,f in os.walk('/kaggle/input/emotion-recognition-dataset/dataset/Angry'):
    for file in f:
        if '.jpg' or '.png' in file:
            paths_angry.append(os.path.join(r,file))
for path in paths_angry:
    img=Image.open(path)
    img=img.resize((128,128))
    img=np.array(img)
    if (img.shape==(128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
paths_happy=[]
for r,d,f in os.walk('/kaggle/input/emotion-recognition-dataset/dataset/Happy'):
    for file in f:
        if '.jpg' or '.png' in file:
            paths_happy.append(os.path.join(r,file))
for path in paths_happy:
    img=Image.open(path)
    img=img.resize((128,128))
    img=np.array(img)
    if (img.shape==(128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[2]]).toarray())

# %%
paths_neutral=[]
for r,d,f in os.walk('/kaggle/input/emotion-recognition-dataset/dataset/Neutral'):
    for file in f:
        if '.jpg' or '.png' in file:
            paths_neutral.append(os.path.join(r,file))
for path in paths_neutral:
    img=Image.open(path)
    img=img.resize((128,128))
    img=np.array(img)
    if (img.shape==(128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[3]]).toarray())

# %%
paths_sad=[]
for r,d,f in os.walk('/kaggle/input/emotion-recognition-dataset/dataset/Sad'):
    for file in f:
        if '.jpg' or '.png' in file:
            paths_sad.append(os.path.join(r,file))
for path in paths_sad:
    img=Image.open(path)
    img=img.resize((128,128))
    img=np.array(img)
    if (img.shape==(128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[4]]).toarray())

# %%
paths_surprise=[]
for r,d,f in os.walk('/kaggle/input/emotion-recognition-dataset/dataset/Surprise'):
    for file in f:
        if '.jpg' or '.png' in file:
            paths_surprise.append(os.path.join(r,file))
for path in paths_surprise:
    img=Image.open(path)
    img=img.resize((128,128))
    img=np.array(img)
    if (img.shape==(128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[5]]).toarray())

# %%
data=np.array(data)
data.shape
# Out:
# (15453, 128, 128, 3)

# %%
result=np.array(result)
result=result.reshape(15453,6)

# %%
# Splitting data between the training, validation and test sets
x_train,x_test,y_train,y_test=train_test_split(data,result,test_size=0.2,shuffle=True,random_state=0)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, shuffle = True, random_state=0)

# Size of each x and y of the training, validation and test sets
print("x_train size:", x_train.shape)
print("y_train size:", y_train.shape)
print("x_test size:", x_test.shape)
print("y_test size:", x_test.shape)
print("x_val size: ", x_val.shape)
print("y_val size: ", y_val.shape, "\n")

# TRAINING SET

# 0 = Ahegao
ahegao_count = 0
# 1 = Angry
angry_count = 0
# 2 = Happy
happy_count = 0
# 3 = Neutral
neutral_count = 0
# 4 = Sad
sad_count = 0
# 5 = Surprise
surprise_count = 0

for array in y_train:
  #print(array, array[0])
  if array[0] == 1:
    ahegao_count += 1
  elif array[1] == 1:
    angry_count += 1
  elif array[2] == 1:
    happy_count += 1
  elif array[3] == 1:
    neutral_count += 1
  elif array[4] == 1:
    sad_count += 1
  elif array[5] == 1:
    surprise_count += 1

print("Training set")
print("Ahegao: ", ahegao_count, "images")
print("Angry: ", angry_count, "images")
print("Happy: ", happy_count, "images")
print("Neutral: ", neutral_count, "images")
print("Sad: ", sad_count, "images")
print("Surprise: ", surprise_count, "images\n")


# VALIDATION SET

# 0 = Ahegao
ahegao_count = 0
# 1 = Angry
angry_count = 0
# 2 = Happy
happy_count = 0
# 3 = Neutral
neutral_count = 0
# 4 = Sad
sad_count = 0
# 5 = Surprise
surprise_count = 0

for array in y_val:
  #print(array, array[0])
  if array[0] == 1:
    ahegao_count += 1
  elif array[1] == 1:
    angry_count += 1
  elif array[2] == 1:
    happy_count += 1
  elif array[3] == 1:
    neutral_count += 1
  elif array[4] == 1:
    sad_count += 1
  elif array[5] == 1:
    surprise_count += 1

print("Validation set")
print("Ahegao: ", ahegao_count, "images")
print("Angry: ", angry_count, "images")
print("Happy: ", happy_count, "images")
print("Neutral: ", neutral_count, "images")
print("Sad: ", sad_count, "images")
print("Surprise: ", surprise_count, "images\n")


# TEST SET

# 0 = Ahegao
ahegao_count = 0
# 1 = Angry
angry_count = 0
# 2 = Happy
happy_count = 0
# 3 = Neutral
neutral_count = 0
# 4 = Sad
sad_count = 0
# 5 = Surprise
surprise_count = 0

for array in y_test:
  #print(array, array[0])
  if array[0] == 1:
    ahegao_count += 1
  elif array[1] == 1:
    angry_count += 1
  elif array[2] == 1:
    happy_count += 1
  elif array[3] == 1:
    neutral_count += 1
  elif array[4] == 1:
    sad_count += 1
  elif array[5] == 1:
    surprise_count += 1

print("Test set")
print("Ahegao: ", ahegao_count, "images")
print("Angry: ", angry_count, "images")
print("Happy: ", happy_count, "images")
print("Neutral: ", neutral_count, "images")
print("Sad: ", sad_count, "images")
print("Surprise: ", surprise_count, "images\n")
# Out:
# x_train size: (9889, 128, 128, 3)
# y_train size: (9889, 6)
# x_test size: (3091, 128, 128, 3)
# y_test size: (3091, 128, 128, 3)
# x_val size:  (2473, 128, 128, 3)
# y_val size:  (2473, 6)
#
# Training set
# Ahegao:  760 images
# Angry:  850 images
# Happy:  2401 images
# Neutral:  2553 images
# Sad:  2529 images
# Surprise:  796 images
#
# Validation set
# Ahegao:  205 images
# Angry:  211 images
# Happy:  598 images
# Neutral:  659 images
# Sad:  606 images
# Surprise:  194 images
#
# Test set
# Ahegao:  240 images
# Angry:  252 images
# Happy:  741 images
# Neutral:  815 images
# Sad:  799 images
# Surprise:  244 images

# %%
import pickle as pkl

# Saving unnormalized training, validation and test sets to pickle files

# Saving training set
with open("train.pkl", "wb") as f:
    pkl.dump([x_train, y_train], f)
    print("training set exported")

# Saving validation set
with open("validation.pkl", "wb") as f:
    pkl.dump([x_val, y_val], f)
    print("validation set exported")

# Saving training set
with open("test.pkl", "wb") as f:
    pkl.dump([x_test, y_test], f)
    print("test set exported")

#to load it
"""
with open("train.pkl", "r") as f:
    train_x, train_y = pkl.load(f)
"""
# Out:
# training set exported
# validation set exported
# test set exported
# '\nwith open("train.pkl", "r") as f:\n    train_x, train_y = pkl.load(f)\n'

# %%
# Normalized sets
x_train_reshaped = x_train.reshape(x_train.shape[0], -1)
x_val_reshaped = x_val.reshape(x_val.shape[0], -1)
x_test_reshaped = x_test.reshape(x_test.shape[0], -1)

print(x_train_reshaped.shape)
print(x_val_reshaped.shape)
print(x_test_reshaped.shape)

scaler = MinMaxScaler()
x_train_normalized = scaler.fit_transform(x_train_reshaped)
x_val_normalized = scaler.transform(x_val_reshaped)
x_test_normalized = scaler.transform(x_test_reshaped)
# Out:
# (9889, 49152)
# (2473, 49152)
# (3091, 49152)
# '\n# Saving normalized training set\nwith open("train_normalized.pkl", "wb") as f:\n    pkl.dump([x_train_normalized, y_train], f)\n    print("training set exported")\n\n# Saving normalized validation set\nwith open("validation_normalized.pkl", "wb") as f:\n    pkl.dump([x_val_normalized, y_val], f)\n    print("validation set exported")\n\n# Saving normalized test set\nwith open("test_normalized.pkl", "wb") as f:\n    pkl.dump([x_test_normalized, y_test], f)\n    print("test set exported")\n'

# %%
# Reshape the normalized data back to its original shape
x_train_normalized = x_train_normalized.reshape(x_train.shape)
x_val_normalized = x_val_normalized.reshape(x_val.shape)
x_test_normalized = x_test_normalized.reshape(x_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-42e0f2b8b5b6> in <cell line: 2>()
#       1 # Reshape the normalized data back to its original shape
# ----> 2 x_train_normalized = x_train_normalized.reshape(x_train.shape)
#       3 x_val_normalized = x_val_normalized.reshape(x_val.shape)
#       4 x_test_normalized = x_test_normalized.reshape(x_test.shape)
#
# NameError: name 'x_train_normalized' is not defined

# %%
# Saving normalized training set
with open("train_normalized.pkl", "wb") as f:
    pkl.dump([x_train_normalized, y_train], f)
    print("training set exported")

# Saving normalized validation set
with open("validation_normalized.pkl", "wb") as f:
    pkl.dump([x_val_normalized, y_val], f)
    print("validation set exported")

# Saving normalized test set
with open("test_normalized.pkl", "wb") as f:
    pkl.dump([x_test_normalized, y_test], f)
    print("test set exported")

# %%
# Loading pickle sets

# training set
with open("train.pkl", "rb") as f:
    x_train, y_train = pkl.load(f)
    print("training set loaded")

# Validation set
with open("validation.pkl", "rb") as f:
    x_val, y_val = pkl.load(f)
    print("validation set loaded")

# testing set
with open("test.pkl", "rb") as f:
    x_test, y_test = pkl.load(f)
    print("testing set loaded")
